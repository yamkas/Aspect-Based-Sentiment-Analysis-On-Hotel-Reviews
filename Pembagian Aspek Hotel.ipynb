# %% [markdown]
# <a href="https://colab.research.google.com/github/yamkas/Aspect-Based-Sentiment-Analysis-On-Hotel-Reviews/blob/main/Pembagian%20Aspek%20Hotel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")

# %%
filename = "3930_Data ReviewHotel XYZ Kota Tangerang.xlsx"
df = pd.read_excel(filename)
df
# Out:
#      nama_hotel        nama_pelanggan rating  \
# 0           XYZ           Cindy C. H.    8.5
# 1           XYZ                 N***a    9.7
# 2           XYZ                 L***a    9.4
# 3           XYZ                Adi P.     10
# 4           XYZ                 G***a     10
# ...         ...                   ...    ...
# 3925        XYZ            Safa Riati      1
# 3926        XYZ  Estika Maulida Priyo      1
# 3927        XYZ                    AG      1
# 3928        XYZ                  Mr G      1
# 3929        XYZ                  Nico      1
#
#                                                  ulasan
# 0     Makanan enak seperti hotel bintang 5, cuma ana...
# 1     Staycation yg nyaman krn ambience dari lobby s...
# 2     staf hotel sangat ramah memberi kamar sesuai k...
# 3     Terima kasih buat staff hotel Rama Adi dan Din...
# 4                bagus staff ramah pelayanan oke banget
# ...                                                 ...
# ...

# %%
import re

# Daftar kata kunci aspek
aspek_kamar = ["kamar", "ranjang", "kasur", "tempat tidur", "toilet", "ac", "bathroom", "shower", "lemari", "jendela", "lampu", "tv"
]
aspek_pelayanan = ["pelayanan", "staf", "service", "resepsionis", "ramah", "helpful", "sopan", "cepat tanggap", "slow response", "senyum","staff", "stafff"]
aspek_kebersihan = ["bersih", "kebersihan", "higienis", "rapih", "debu", "bau", "kotor", "sampah", "toilet bersih", "handuk kotor"]
aspek_fasilitas = ["wifi", "tv", "kolam renang", "gym", "lift", "sarapan", "breakfast", "parkir", "lounge", "air panas", "shuttle", "bar"
]

# Fungsi untuk mengecek aspek dalam ulasan
def tentukan_aspek(ulasan, keywords):
    return any(re.search(rf"\b{kw}\b", ulasan, re.IGNORECASE) for kw in keywords)

# Menambahkan kolom aspek berdasarkan kata kunci
df["aspek_kamar"] = df["ulasan"].apply(lambda x: tentukan_aspek(x, aspek_kamar))
df["aspek_pelayanan"] = df["ulasan"].apply(lambda x: tentukan_aspek(x, aspek_pelayanan))
df["aspek_kebersihan"] = df["ulasan"].apply(lambda x: tentukan_aspek(x, aspek_kebersihan))
df["aspek_fasilitas"] = df["ulasan"].apply(lambda x: tentukan_aspek(x, aspek_fasilitas))


df.head()
# Out:
#   nama_hotel nama_pelanggan rating  \
# 0        XYZ    Cindy C. H.    8.5
# 1        XYZ          N***a    9.7
# 2        XYZ          L***a    9.4
# 3        XYZ         Adi P.     10
# 4        XYZ          G***a     10
#
#                                               ulasan  aspek_kamar  \
# 0  Makanan enak seperti hotel bintang 5, cuma ana...         True
# 1  Staycation yg nyaman krn ambience dari lobby s...        False
# 2  staf hotel sangat ramah memberi kamar sesuai k...         True
# 3  Terima kasih buat staff hotel Rama Adi dan Din...         True
# 4             bagus staff ramah pelayanan oke banget        False
#
#    aspek_pelayanan  aspek_kebersihan  aspek_fasilitas
# 0             True             False            False
# 1            False             False            False
# 2             True             False            False
# 3             True              True            False
# 4             True             False            False

# %%
# Mengunduh hasil aspek dalam format Excel
df.to_excel("hasil_aspek_baru.xlsx", index=False)
print("File 'hasil_aspek.xlsx' telah diunduh.")
# Out:
# File 'hasil_aspek.xlsx' telah diunduh.
